# %%
import os
import pandas as pd

# Step 1: 找到重复的股票代码
def find_duplicates(df):
    # 获取重复股票代码及其新闻发布时间
    duplicates = df[df["股票代码"].duplicated(keep=False)]
    return duplicates[["股票代码", "新闻发布时间"]]

# Step 2: 保存重复股票代码到 Excel 文件
def save_duplicates_to_excel(duplicates, output_path):
    duplicates.to_excel(output_path, index=False)
    print(f"重复股票代码已保存到 {output_path}")

# Step 3: 从文件夹中读取文件名并删除重复的股票代码文件
def remove_duplicate_files(folder_path, duplicate_codes):
    files = os.listdir(folder_path)
    for file in files:
        # 提取文件名中的股票代码
        stock_code = os.path.splitext(file)[0]
        if stock_code in duplicate_codes:
            file_path = os.path.join(folder_path, file)
            os.remove(file_path)
            print(f"已删除文件: {file_path}")

# Step 4: 主程序
def main():
    # 读取数据（假设你的数据存储在 data.csv 中）
    df = pd.read_excel('data_china.xlsx',sheet_name=1,dtype={'股票代码': str})

    # 找到重复股票代码
    duplicates = find_duplicates(df)
    # 保存到 Excel 文件
    save_duplicates_to_excel(duplicates, "duplicates_test.xlsx")

    # 获取重复股票代码列表
    duplicate_codes = duplicates["股票代码"].unique()

    # 删除文件夹中与重复股票代码相关的文件
    folder_path = "D:\mycodelife\workshop\\fake_finance\\codes"  # 修改为你的文件夹路径
    remove_duplicate_files(folder_path, duplicate_codes)

# 执行主程序
if __name__ == "__main__":
    main()
# Out:
# 重复股票代码已保存到 duplicates_test.xlsx
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000078.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000561.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000651.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000662.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000673.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000799.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000818.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000939.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\000980.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002213.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002331.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002359.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002405.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002456.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002468.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002509.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002564.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\002671.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300104.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300302.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300332.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300522.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300587.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300773.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\300803.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600053.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600057.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600060.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600061.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600074.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600075.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600137.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600166.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600238.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600240.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600265.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600332.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600346.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600351.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600370.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600381.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600393.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600401.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600418.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600485.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600487.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600499.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600530.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600569.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600570.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600610.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600645.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600671.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600682.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600702.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600771.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600781.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600810.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600853.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600882.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\600933.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\601012.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\601116.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\601599.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\601727.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\601766.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\601777.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\603023.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\603189.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\603385.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\603599.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\603773.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\603866.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\688068.csv
# 已删除文件: D:\mycodelife\workshop\fake_finance\codes\688101.csv
